# %%
# !pip install huggingface_hub

# %%
from huggingface_hub import hf_hub_download
import pandas as pd
import joblib

# Configuration
REPO_ID = "Alok8732/Movie_Recommnedation_Artifacts"

print("Fetching artifacts from Hugging Face...")

# 1. Load the Dataframe
parquet_path = hf_hub_download(repo_id=REPO_ID, filename="movies_fully_cleaned.parquet", repo_type="dataset")
df = pd.read_parquet(parquet_path)
df = df.reset_index(drop=True)
# 2. Load the TF-IDF Matrix
matrix_path = hf_hub_download(repo_id=REPO_ID, filename="tfidf_matrix.pkl", repo_type="dataset")
tfidf_matrix = joblib.load(matrix_path)

# 3. Load the Vectorizer (Optional, but good to have)
vectorizer_path = hf_hub_download(repo_id=REPO_ID, filename="tfidf_vectorizer.pkl", repo_type="dataset")
tfidf_vectorizer = joblib.load(vectorizer_path)

print(f"✅ Success! Loaded {len(df)} movies and a {tfidf_matrix.shape} similarity matrix.")
# Out:
# Fetching artifacts from Hugging Face...
# ✅ Success! Loaded 503398 movies and a (503398, 50000) similarity matrix.

# %%
import pandas as pd
import joblib
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
# ADD THESE TWO LINES:
from thefuzz import process, fuzz
from IPython.display import display

# %%
# Create the movie index map to link titles to matrix rows
movie_index_map = pd.Series(df.index, index=df["title"]).drop_duplicates()
print(f"Index map created for {len(movie_index_map)} unique movies.")
# Out:
# Index map created for 503398 unique movies.

# %%
def get_recommendations(title, n=12, alpha=0.85, beta=0.15):
    # 1. ENSURE MAP EXISTS
    global movie_index_map
    if 'movie_index_map' not in globals():
        movie_index_map = pd.Series(df.index, index=df["title"]).drop_duplicates()

    # 2. SCALABLE FUZZY MATCHING
    all_titles = df['title'].unique()
    best_match, score = process.extractOne(title, all_titles, scorer=fuzz.WRatio)
    
    if score < 60 or len(title.strip()) < 3:
        print(f"⚠️ Search term '{title}' is too vague.")
        return None
    
    # 3. EXTRACT MATRIX INDEX
    idx_entry = movie_index_map[best_match]
    idx = idx_entry.iloc[0] if isinstance(idx_entry, pd.Series) else idx_entry
    
    # 4. COMPUTE HYBRID SCORE
    sim_scores = cosine_similarity(tfidf_matrix[idx], tfidf_matrix).flatten()
    log_pop = np.log1p(df['vote_count'])
    pop_norm = (log_pop - log_pop.min()) / (log_pop.max() - log_pop.min())
    
    hybrid_scores = (alpha * sim_scores) + (beta * pop_norm.values)
    
    # 5. EFFICIENT SELECTION WITH ZERO-VOTE PENALTY
    # We grab more than 'n' results initially to ensure we have room to re-sort
    k_search = n * 2 
    partition_idx = np.argpartition(hybrid_scores, -k_search)[-k_search:]
    
    # 6. FORMAT AND FINAL SORT
    res = df.iloc[partition_idx].copy()
    res['similarity'] = sim_scores[partition_idx]
    res['hybrid_score'] = hybrid_scores[partition_idx]
    
    # REMOVE THE SEARCHED MOVIE ITSELF
    res = res[res.index != idx]
    
    # SECONDARY SORTING: Sort by hybrid_score first, then by vote_count
    # This ensures that if scores are similar, the one with more votes wins.
    # It also naturally pushes 0-vote movies lower.
    res = res.sort_values(by=['hybrid_score', 'vote_count'], ascending=False).head(n)
    
    print(f"✅ Found matches for: '{best_match}'")
    return res[['title', 'genres', 'vote_count', 'similarity', 'hybrid_score']].reset_index(drop=True)

# %%
# Test with a popular title
results = get_recommendations("Avata", n=12)

if results is not None:
    display(results.style.hide(axis='index'))
# Out:
# ✅ Found matches for: 'Avatar'
# <style type="text/css">
# </style>
# <table id="T_c7fed">
#   <thead>
#     <tr>
#       <th id="T_c7fed_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_c7fed_level0_col1" class="col_heading level0 col1" >genres</th>
#       <th id="T_c7fed_level0_col2" class="col_heading level0 col2" >vote_count</th>
#       <th id="T_c7fed_level0_col3" class="col_heading level0 col3" >similarity</th>
#       <th id="T_c7fed_level0_col4" class="col_heading level0 col4" >hybrid_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c7fed_row0_col0" class="data row0 col0" >Woman of the Year</td>
#       <td id="T_c7fed_row0_col1" class="data row0 col1" >Comedy, Romance, Drama</td>
#       <td id="T_c7fed_row0_col2" class="data row0 col2" >160.000000</td>
#       <td id="T_c7fed_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_c7fed_row0_col4" class="data row0 col4" >0.922151</td>
#     </tr>
#     <tr>
#       <td id="T_c7fed_row1_col0" class="data row1 col0" >Eine fast perfekte Bescherung</td>
#       <td id="T_c7fed_row1_col1" class="data row1 col1" >Comedy, Romance, Drama</td>
#       <td id="T_c7fed_row1_col2" class="data row1 col2" >2.000000</td>
#       <td id="T_c7fed_row1_col3" class="data row1 col3" >0.390775</td>
#       <td id="T_c7fed_row1_col4" class="data row1 col4" >0.347758</td>
#     </tr>
#     <tr>
#       <td id="T_c7fed_row2_col0" class="data row2 col0" >Choose the Life I Want</td>
#       <td id="T_c7fed_row2_col1" class="data row2 col1" >Comedy, Romance, Drama</td>
#       <td id="T_c7fed_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_c7fed_row2_col3" class="data row2 col3" >0.407965</td>
#       <td id="T_c7fed_row2_col4" class="data row2 col4" >0.346770</td>
#     </tr>
#     <tr>
#       <td id="T_c7fed_row3_col0" class="data row3 col0" >Badhaai Ho</td>
#       <td id="T_c7fed_row3_col1" class="data row3 col1" >Comedy, Romance, Drama</td>
#       <td id="T_c7fed_row3_col2" class="data row3 col2" >144.000000</td>
#       <td id="T_c7fed_row3_col3" class="data row3 col3" >0.303338</td>
#       <td id="T_c7fed_row3_col4" class="data row3 col4" >0.328503</td>
#     </tr>
#     <tr>
#       <td id="T_c7fed_row4_col0" class="data row4 col0" >Love Actually</td>
#       <td id="T_c7fed_row4_col1" class="data row4 col1" >Comedy, Romance, Drama</td>
#       <td id="T_c7fed_row4_col2" class="data row4 col2" >7217.000000</td>
#       <td id="T_c7fed_row4_col3" class="data row4 col3" >0.236485</td>
#       <td id="T_c7fed_row4_col4" class="data row4 col4" >0.327162</td>
#     </tr>
#     <tr>
#       <td id="T_c7fed_row5_col0" class="data row5 col0" >The Proposal</td>
#       <td id="T_c7fed_row5_col1" class="data row5 col1" >Comedy, Romance, Drama</td>
#       <td id="T_c7fed_row5_col2" class="data row5 col2" >7296.000000</td>
#       <td id="T_c7fed_row5_col3" class="data row5 col3" >0.232354</td>
#       <td id="T_c7fed_row5_col4" class="data row5 col4" >0.323806</td>
#     </tr>
#     <tr>
#       <td id="T_c7fed_row6_col0" class="data row6 col0" >The Circus</td>
#       <td id="T_c7fed_row6_col1" class="data row6 col1" >Comedy, Romance, Drama</td>
#       <td id="T_c7fed_row6_col2" class="data row6 col2" >860.000000</td>
#       <td id="T_c7fed_row6_col3" class="data row6 col3" >0.266821</td>
#       <td id="T_c7fed_row6_col4" class="data row6 col4" >0.322757</td>
#     </tr>
#     <tr>
#       <td id="T_c7fed_row7_col0" class="data row7 col0" >The Oranges</td>
#       <td id="T_c7fed_row7_col1" class="data row7 col1" >Comedy, Romance, Drama</td>
#       <td id="T_c7fed_row7_col2" class="data row7 col2" >502.000000</td>
#       <td id="T_c7fed_row7_col3" class="data row7 col3" >0.274297</td>
#       <td id="T_c7fed_row7_col4" class="data row7 col4" >0.321479</td>
#     </tr>
#     <tr>
#       <td id="T_c7fed_row8_col0" class="data row8 col0" >Show Me Love</td>
#       <td id="T_c7fed_row8_col1" class="data row8 col1" >Comedy, Romance, Drama</td>
#       <td id="T_c7fed_row8_col2" class="data row8 col2" >574.000000</td>
#       <td id="T_c7fed_row8_col3" class="data row8 col3" >0.271886</td>
#       <td id="T_c7fed_row8_col4" class="data row8 col4" >0.321330</td>
#     </tr>
#     <tr>
#       <td id="T_c7fed_row9_col0" class="data row9 col0" >Saving Face</td>
#       <td id="T_c7fed_row9_col1" class="data row9 col1" >Comedy, Romance, Drama</td>
#       <td id="T_c7fed_row9_col2" class="data row9 col2" >247.000000</td>
#       <td id="T_c7fed_row9_col3" class="data row9 col3" >0.280663</td>
#       <td id="T_c7fed_row9_col4" class="data row9 col4" >0.316850</td>
#     </tr>
#     <tr>
#       <td id="T_c7fed_row10_col0" class="data row10 col0" >Tanu Weds Manu</td>
#       <td id="T_c7fed_row10_col1" class="data row10 col1" >Comedy, Romance, Drama</td>
#       <td id="T_c7fed_row10_col2" class="data row10 col2" >97.000000</td>
#       <td id="T_c7fed_row10_col3" class="data row10 col3" >0.296054</td>
#       <td id="T_c7fed_row10_col4" class="data row10 col4" >0.316749</td>
#     </tr>
#     <tr>
#       <td id="T_c7fed_row11_col0" class="data row11 col0" >Knocked Up</td>
#       <td id="T_c7fed_row11_col1" class="data row11 col1" >Comedy, Romance, Drama</td>
#       <td id="T_c7fed_row11_col2" class="data row11 col2" >4155.000000</td>
#       <td id="T_c7fed_row11_col3" class="data row11 col3" >0.233200</td>
#       <td id="T_c7fed_row11_col4" class="data row11 col4" >0.316531</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Test with a popular title
results = get_recommendations("Fast X", n=12)

if results is not None:
    display(results.style.hide(axis='index'))
# Out:
# ✅ Recommendations for: 'Fast X'
# <style type="text/css">
# </style>
# <table id="T_be63a">
#   <thead>
#     <tr>
#       <th id="T_be63a_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_be63a_level0_col1" class="col_heading level0 col1" >genres</th>
#       <th id="T_be63a_level0_col2" class="col_heading level0 col2" >vote_count</th>
#       <th id="T_be63a_level0_col3" class="col_heading level0 col3" >similarity</th>
#       <th id="T_be63a_level0_col4" class="col_heading level0 col4" >hybrid_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_be63a_row0_col0" class="data row0 col0" >Tel chi el telùn</td>
#       <td id="T_be63a_row0_col1" class="data row0 col1" >Comedy</td>
#       <td id="T_be63a_row0_col2" class="data row0 col2" >328.000000</td>
#       <td id="T_be63a_row0_col3" class="data row0 col3" >0.198643</td>
#       <td id="T_be63a_row0_col4" class="data row0 col4" >0.251146</td>
#     </tr>
#     <tr>
#       <td id="T_be63a_row1_col0" class="data row1 col0" >Un Natale stupefacente</td>
#       <td id="T_be63a_row1_col1" class="data row1 col1" >Comedy</td>
#       <td id="T_be63a_row1_col2" class="data row1 col2" >156.000000</td>
#       <td id="T_be63a_row1_col3" class="data row1 col3" >0.198746</td>
#       <td id="T_be63a_row1_col4" class="data row1 col4" >0.240729</td>
#     </tr>
#     <tr>
#       <td id="T_be63a_row2_col0" class="data row2 col0" >Amore, bugie e calcetto</td>
#       <td id="T_be63a_row2_col1" class="data row2 col1" >Comedy</td>
#       <td id="T_be63a_row2_col2" class="data row2 col2" >214.000000</td>
#       <td id="T_be63a_row2_col3" class="data row2 col3" >0.188393</td>
#       <td id="T_be63a_row2_col4" class="data row2 col4" >0.236392</td>
#     </tr>
#     <tr>
#       <td id="T_be63a_row3_col0" class="data row3 col0" >Kev Adams & Gad Elmaleh - Kev Gad, Tout est possible</td>
#       <td id="T_be63a_row3_col1" class="data row3 col1" >Comedy</td>
#       <td id="T_be63a_row3_col2" class="data row3 col2" >95.000000</td>
#       <td id="T_be63a_row3_col3" class="data row3 col3" >0.198746</td>
#       <td id="T_be63a_row3_col4" class="data row3 col4" >0.233744</td>
#     </tr>
#     <tr>
#       <td id="T_be63a_row4_col0" class="data row4 col0" >Gad Elmaleh : Sans tambour</td>
#       <td id="T_be63a_row4_col1" class="data row4 col1" >Comedy</td>
#       <td id="T_be63a_row4_col2" class="data row4 col2" >111.000000</td>
#       <td id="T_be63a_row4_col3" class="data row4 col3" >0.193975</td>
#       <td id="T_be63a_row4_col4" class="data row4 col4" >0.231877</td>
#     </tr>
#     <tr>
#       <td id="T_be63a_row5_col0" class="data row5 col0" >Caccia al tesoro</td>
#       <td id="T_be63a_row5_col1" class="data row5 col1" >Comedy</td>
#       <td id="T_be63a_row5_col2" class="data row5 col2" >82.000000</td>
#       <td id="T_be63a_row5_col3" class="data row5 col3" >0.198746</td>
#       <td id="T_be63a_row5_col4" class="data row5 col4" >0.231678</td>
#     </tr>
#     <tr>
#       <td id="T_be63a_row6_col0" class="data row6 col0" >El tatuaje</td>
#       <td id="T_be63a_row6_col1" class="data row6 col1" >Comedy</td>
#       <td id="T_be63a_row6_col2" class="data row6 col2" >73.000000</td>
#       <td id="T_be63a_row6_col3" class="data row6 col3" >0.198746</td>
#       <td id="T_be63a_row6_col4" class="data row6 col4" >0.230048</td>
#     </tr>
#     <tr>
#       <td id="T_be63a_row7_col0" class="data row7 col0" >Una canzone per te</td>
#       <td id="T_be63a_row7_col1" class="data row7 col1" >Comedy</td>
#       <td id="T_be63a_row7_col2" class="data row7 col2" >69.000000</td>
#       <td id="T_be63a_row7_col3" class="data row7 col3" >0.198746</td>
#       <td id="T_be63a_row7_col4" class="data row7 col4" >0.229259</td>
#     </tr>
#     <tr>
#       <td id="T_be63a_row8_col0" class="data row8 col0" >La mia vita a stelle e strisce</td>
#       <td id="T_be63a_row8_col1" class="data row8 col1" >Comedy</td>
#       <td id="T_be63a_row8_col2" class="data row8 col2" >57.000000</td>
#       <td id="T_be63a_row8_col3" class="data row8 col3" >0.198746</td>
#       <td id="T_be63a_row8_col4" class="data row8 col4" >0.226589</td>
#     </tr>
#     <tr>
#       <td id="T_be63a_row9_col0" class="data row9 col0" >Kyan Khojandi : Pulsions</td>
#       <td id="T_be63a_row9_col1" class="data row9 col1" >Comedy</td>
#       <td id="T_be63a_row9_col2" class="data row9 col2" >54.000000</td>
#       <td id="T_be63a_row9_col3" class="data row9 col3" >0.198746</td>
#       <td id="T_be63a_row9_col4" class="data row9 col4" >0.225835</td>
#     </tr>
#     <tr>
#       <td id="T_be63a_row10_col0" class="data row10 col0" >Malcriados</td>
#       <td id="T_be63a_row10_col1" class="data row10 col1" >Comedy</td>
#       <td id="T_be63a_row10_col2" class="data row10 col2" >54.000000</td>
#       <td id="T_be63a_row10_col3" class="data row10 col3" >0.198746</td>
#       <td id="T_be63a_row10_col4" class="data row10 col4" >0.225835</td>
#     </tr>
#     <tr>
#       <td id="T_be63a_row11_col0" class="data row11 col0" >Jamel - 100% Debbouze</td>
#       <td id="T_be63a_row11_col1" class="data row11 col1" >Comedy</td>
#       <td id="T_be63a_row11_col2" class="data row11 col2" >39.000000</td>
#       <td id="T_be63a_row11_col3" class="data row11 col3" >0.198746</td>
#       <td id="T_be63a_row11_col4" class="data row11 col4" >0.221313</td>
#     </tr>
#   </tbody>
# </table>

# %%
results = get_recommendations("Dhurandhar", n=12)

if results is not None:
    display(results.style.hide(axis='index'))
# Out:
# ✅ Found matches for: 'Dhurandhar'
# <style type="text/css">
# </style>
# <table id="T_ee29b">
#   <thead>
#     <tr>
#       <th id="T_ee29b_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_ee29b_level0_col1" class="col_heading level0 col1" >genres</th>
#       <th id="T_ee29b_level0_col2" class="col_heading level0 col2" >vote_count</th>
#       <th id="T_ee29b_level0_col3" class="col_heading level0 col3" >similarity</th>
#       <th id="T_ee29b_level0_col4" class="col_heading level0 col4" >hybrid_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ee29b_row0_col0" class="data row0 col0" >The Great Escape</td>
#       <td id="T_ee29b_row0_col1" class="data row0 col1" >Action, Thriller</td>
#       <td id="T_ee29b_row0_col2" class="data row0 col2" >5.000000</td>
#       <td id="T_ee29b_row0_col3" class="data row0 col3" >0.422941</td>
#       <td id="T_ee29b_row0_col4" class="data row0 col4" >0.384941</td>
#     </tr>
#     <tr>
#       <td id="T_ee29b_row1_col0" class="data row1 col0" >Adventure King</td>
#       <td id="T_ee29b_row1_col1" class="data row1 col1" >Action, Thriller</td>
#       <td id="T_ee29b_row1_col2" class="data row1 col2" >6.000000</td>
#       <td id="T_ee29b_row1_col3" class="data row1 col3" >0.418061</td>
#       <td id="T_ee29b_row1_col4" class="data row1 col4" >0.382982</td>
#     </tr>
#     <tr>
#       <td id="T_ee29b_row2_col0" class="data row2 col0" >Sí matarás</td>
#       <td id="T_ee29b_row2_col1" class="data row2 col1" >Action, Thriller</td>
#       <td id="T_ee29b_row2_col2" class="data row2 col2" >2.000000</td>
#       <td id="T_ee29b_row2_col3" class="data row2 col3" >0.422941</td>
#       <td id="T_ee29b_row2_col4" class="data row2 col4" >0.375099</td>
#     </tr>
#     <tr>
#       <td id="T_ee29b_row3_col0" class="data row3 col0" >Firasat</td>
#       <td id="T_ee29b_row3_col1" class="data row3 col1" >Action, Thriller</td>
#       <td id="T_ee29b_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_ee29b_row3_col3" class="data row3 col3" >0.422941</td>
#       <td id="T_ee29b_row3_col4" class="data row3 col4" >0.369342</td>
#     </tr>
#     <tr>
#       <td id="T_ee29b_row4_col0" class="data row4 col0" >Eighteen Arhats of Shaolin Temple</td>
#       <td id="T_ee29b_row4_col1" class="data row4 col1" >Action, Thriller</td>
#       <td id="T_ee29b_row4_col2" class="data row4 col2" >2.000000</td>
#       <td id="T_ee29b_row4_col3" class="data row4 col3" >0.413054</td>
#       <td id="T_ee29b_row4_col4" class="data row4 col4" >0.366695</td>
#     </tr>
#     <tr>
#       <td id="T_ee29b_row5_col0" class="data row5 col0" >John Wick</td>
#       <td id="T_ee29b_row5_col1" class="data row5 col1" >Action, Thriller</td>
#       <td id="T_ee29b_row5_col2" class="data row5 col2" >20393.000000</td>
#       <td id="T_ee29b_row5_col3" class="data row5 col3" >0.262205</td>
#       <td id="T_ee29b_row5_col4" class="data row5 col4" >0.363772</td>
#     </tr>
#     <tr>
#       <td id="T_ee29b_row6_col0" class="data row6 col0" >Gavanam</td>
#       <td id="T_ee29b_row6_col1" class="data row6 col1" >Action, Thriller</td>
#       <td id="T_ee29b_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_ee29b_row6_col3" class="data row6 col3" >0.422941</td>
#       <td id="T_ee29b_row6_col4" class="data row6 col4" >0.359500</td>
#     </tr>
#     <tr>
#       <td id="T_ee29b_row7_col0" class="data row7 col0" >Пассажиры</td>
#       <td id="T_ee29b_row7_col1" class="data row7 col1" >Action, Thriller</td>
#       <td id="T_ee29b_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_ee29b_row7_col3" class="data row7 col3" >0.422941</td>
#       <td id="T_ee29b_row7_col4" class="data row7 col4" >0.359500</td>
#     </tr>
#     <tr>
#       <td id="T_ee29b_row8_col0" class="data row8 col0" >Fuerza Máxima</td>
#       <td id="T_ee29b_row8_col1" class="data row8 col1" >Action, Thriller</td>
#       <td id="T_ee29b_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_ee29b_row8_col3" class="data row8 col3" >0.422941</td>
#       <td id="T_ee29b_row8_col4" class="data row8 col4" >0.359500</td>
#     </tr>
#     <tr>
#       <td id="T_ee29b_row9_col0" class="data row9 col0" >Mayonaka no Super Car</td>
#       <td id="T_ee29b_row9_col1" class="data row9 col1" >Action, Thriller</td>
#       <td id="T_ee29b_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_ee29b_row9_col3" class="data row9 col3" >0.422941</td>
#       <td id="T_ee29b_row9_col4" class="data row9 col4" >0.359500</td>
#     </tr>
#     <tr>
#       <td id="T_ee29b_row10_col0" class="data row10 col0" >Manyam</td>
#       <td id="T_ee29b_row10_col1" class="data row10 col1" >Action, Thriller</td>
#       <td id="T_ee29b_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_ee29b_row10_col3" class="data row10 col3" >0.420139</td>
#       <td id="T_ee29b_row10_col4" class="data row10 col4" >0.357118</td>
#     </tr>
#     <tr>
#       <td id="T_ee29b_row11_col0" class="data row11 col0" >The Red Phone: Manhunt</td>
#       <td id="T_ee29b_row11_col1" class="data row11 col1" >Action, Thriller</td>
#       <td id="T_ee29b_row11_col2" class="data row11 col2" >7.000000</td>
#       <td id="T_ee29b_row11_col3" class="data row11 col3" >0.385237</td>
#       <td id="T_ee29b_row11_col4" class="data row11 col4" >0.356978</td>
#     </tr>
#   </tbody>
# </table>

# %%
results = get_recommendations("ek tha tiger", n=12)

if results is not None:
    display(results.style.hide(axis='index'))
# Out:
# ✅ Found matches for: 'Ek Tha Tiger'
# <style type="text/css">
# </style>
# <table id="T_4ae43">
#   <thead>
#     <tr>
#       <th id="T_4ae43_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_4ae43_level0_col1" class="col_heading level0 col1" >genres</th>
#       <th id="T_4ae43_level0_col2" class="col_heading level0 col2" >vote_count</th>
#       <th id="T_4ae43_level0_col3" class="col_heading level0 col3" >similarity</th>
#       <th id="T_4ae43_level0_col4" class="col_heading level0 col4" >hybrid_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4ae43_row0_col0" class="data row0 col0" >Hero Naam Yaad Rakhi</td>
#       <td id="T_4ae43_row0_col1" class="data row0 col1" >Action, Thriller, Romance</td>
#       <td id="T_4ae43_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_4ae43_row0_col3" class="data row0 col3" >0.652682</td>
#       <td id="T_4ae43_row0_col4" class="data row0 col4" >0.564622</td>
#     </tr>
#     <tr>
#       <td id="T_4ae43_row1_col0" class="data row1 col0" >Assassin Training Course</td>
#       <td id="T_4ae43_row1_col1" class="data row1 col1" >Action, Thriller, Romance</td>
#       <td id="T_4ae43_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_4ae43_row1_col3" class="data row1 col3" >0.643897</td>
#       <td id="T_4ae43_row1_col4" class="data row1 col4" >0.547312</td>
#     </tr>
#     <tr>
#       <td id="T_4ae43_row2_col0" class="data row2 col0" >Stopover Tokyo</td>
#       <td id="T_4ae43_row2_col1" class="data row2 col1" >Action, Thriller, Romance</td>
#       <td id="T_4ae43_row2_col2" class="data row2 col2" >7.000000</td>
#       <td id="T_4ae43_row2_col3" class="data row2 col3" >0.607204</td>
#       <td id="T_4ae43_row2_col4" class="data row2 col4" >0.545649</td>
#     </tr>
#     <tr>
#       <td id="T_4ae43_row3_col0" class="data row3 col0" >The Tourist</td>
#       <td id="T_4ae43_row3_col1" class="data row3 col1" >Action, Thriller, Romance</td>
#       <td id="T_4ae43_row3_col2" class="data row3 col2" >5651.000000</td>
#       <td id="T_4ae43_row3_col3" class="data row3 col3" >0.473448</td>
#       <td id="T_4ae43_row3_col4" class="data row3 col4" >0.525108</td>
#     </tr>
#     <tr>
#       <td id="T_4ae43_row4_col0" class="data row4 col0" >Collision</td>
#       <td id="T_4ae43_row4_col1" class="data row4 col1" >Action, Thriller, Romance</td>
#       <td id="T_4ae43_row4_col2" class="data row4 col2" >105.000000</td>
#       <td id="T_4ae43_row4_col3" class="data row4 col3" >0.535813</td>
#       <td id="T_4ae43_row4_col4" class="data row4 col4" >0.521657</td>
#     </tr>
#     <tr>
#       <td id="T_4ae43_row5_col0" class="data row5 col0" >Ghat Pratyaghat</td>
#       <td id="T_4ae43_row5_col1" class="data row5 col1" >Action, Thriller, Romance</td>
#       <td id="T_4ae43_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_4ae43_row5_col3" class="data row5 col3" >0.598365</td>
#       <td id="T_4ae43_row5_col4" class="data row5 col4" >0.508610</td>
#     </tr>
#     <tr>
#       <td id="T_4ae43_row6_col0" class="data row6 col0" >X</td>
#       <td id="T_4ae43_row6_col1" class="data row6 col1" >Action, Thriller, Romance</td>
#       <td id="T_4ae43_row6_col2" class="data row6 col2" >312.000000</td>
#       <td id="T_4ae43_row6_col3" class="data row6 col3" >0.497855</td>
#       <td id="T_4ae43_row6_col4" class="data row6 col4" >0.504768</td>
#     </tr>
#     <tr>
#       <td id="T_4ae43_row7_col0" class="data row7 col0" >Ko 2</td>
#       <td id="T_4ae43_row7_col1" class="data row7 col1" >Action, Thriller, Romance</td>
#       <td id="T_4ae43_row7_col2" class="data row7 col2" >6.000000</td>
#       <td id="T_4ae43_row7_col3" class="data row7 col3" >0.548310</td>
#       <td id="T_4ae43_row7_col4" class="data row7 col4" >0.493694</td>
#     </tr>
#     <tr>
#       <td id="T_4ae43_row8_col0" class="data row8 col0" >Saamy²</td>
#       <td id="T_4ae43_row8_col1" class="data row8 col1" >Action, Thriller, Romance</td>
#       <td id="T_4ae43_row8_col2" class="data row8 col2" >14.000000</td>
#       <td id="T_4ae43_row8_col3" class="data row8 col3" >0.510860</td>
#       <td id="T_4ae43_row8_col4" class="data row8 col4" >0.472683</td>
#     </tr>
#     <tr>
#       <td id="T_4ae43_row9_col0" class="data row9 col0" >No More Dirty Deals</td>
#       <td id="T_4ae43_row9_col1" class="data row9 col1" >Action, Thriller, Romance</td>
#       <td id="T_4ae43_row9_col2" class="data row9 col2" >1.000000</td>
#       <td id="T_4ae43_row9_col3" class="data row9 col3" >0.541367</td>
#       <td id="T_4ae43_row9_col4" class="data row9 col4" >0.470004</td>
#     </tr>
#     <tr>
#       <td id="T_4ae43_row10_col0" class="data row10 col0" >Sulthan</td>
#       <td id="T_4ae43_row10_col1" class="data row10 col1" >Action, Thriller, Romance</td>
#       <td id="T_4ae43_row10_col2" class="data row10 col2" >20.000000</td>
#       <td id="T_4ae43_row10_col3" class="data row10 col3" >0.460369</td>
#       <td id="T_4ae43_row10_col4" class="data row10 col4" >0.434543</td>
#     </tr>
#     <tr>
#       <td id="T_4ae43_row11_col0" class="data row11 col0" >Messiah</td>
#       <td id="T_4ae43_row11_col1" class="data row11 col1" >Action, Thriller, Romance</td>
#       <td id="T_4ae43_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_4ae43_row11_col3" class="data row11 col3" >0.496290</td>
#       <td id="T_4ae43_row11_col4" class="data row11 col4" >0.421847</td>
#     </tr>
#   </tbody>
# </table>

# %%
results = get_recommendations("pushpa", n=12)

if results is not None:
    display(results.style.hide(axis='index'))
# Out:
# ✅ Found matches for: 'Push'
# <style type="text/css">
# </style>
# <table id="T_c1eff">
#   <thead>
#     <tr>
#       <th id="T_c1eff_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_c1eff_level0_col1" class="col_heading level0 col1" >genres</th>
#       <th id="T_c1eff_level0_col2" class="col_heading level0 col2" >vote_count</th>
#       <th id="T_c1eff_level0_col3" class="col_heading level0 col3" >similarity</th>
#       <th id="T_c1eff_level0_col4" class="col_heading level0 col4" >hybrid_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c1eff_row0_col0" class="data row0 col0" >Predator</td>
#       <td id="T_c1eff_row0_col1" class="data row0 col1" >Science Fiction, Action, Adventure, Thriller</td>
#       <td id="T_c1eff_row0_col2" class="data row0 col2" >8785.000000</td>
#       <td id="T_c1eff_row0_col3" class="data row0 col3" >0.383962</td>
#       <td id="T_c1eff_row0_col4" class="data row0 col4" >0.455309</td>
#     </tr>
#     <tr>
#       <td id="T_c1eff_row1_col0" class="data row1 col0" >Star Trek V: The Final Frontier</td>
#       <td id="T_c1eff_row1_col1" class="data row1 col1" >Science Fiction, Action, Adventure, Thriller</td>
#       <td id="T_c1eff_row1_col2" class="data row1 col2" >1260.000000</td>
#       <td id="T_c1eff_row1_col3" class="data row1 col3" >0.400491</td>
#       <td id="T_c1eff_row1_col4" class="data row1 col4" >0.441794</td>
#     </tr>
#     <tr>
#       <td id="T_c1eff_row2_col0" class="data row2 col0" >Star Trek III: The Search for Spock</td>
#       <td id="T_c1eff_row2_col1" class="data row2 col1" >Science Fiction, Action, Adventure, Thriller</td>
#       <td id="T_c1eff_row2_col2" class="data row2 col2" >1461.000000</td>
#       <td id="T_c1eff_row2_col3" class="data row2 col3" >0.384276</td>
#       <td id="T_c1eff_row2_col4" class="data row2 col4" >0.430111</td>
#     </tr>
#     <tr>
#       <td id="T_c1eff_row3_col0" class="data row3 col0" >Gemini Man</td>
#       <td id="T_c1eff_row3_col1" class="data row3 col1" >Science Fiction, Action, Adventure, Thriller</td>
#       <td id="T_c1eff_row3_col2" class="data row3 col2" >5344.000000</td>
#       <td id="T_c1eff_row3_col3" class="data row3 col3" >0.357098</td>
#       <td id="T_c1eff_row3_col4" class="data row3 col4" >0.425417</td>
#     </tr>
#     <tr>
#       <td id="T_c1eff_row4_col0" class="data row4 col0" >Star Trek: Insurrection</td>
#       <td id="T_c1eff_row4_col1" class="data row4 col1" >Science Fiction, Action, Adventure, Thriller</td>
#       <td id="T_c1eff_row4_col2" class="data row4 col2" >1311.000000</td>
#       <td id="T_c1eff_row4_col3" class="data row4 col3" >0.373169</td>
#       <td id="T_c1eff_row4_col4" class="data row4 col4" >0.419133</td>
#     </tr>
#     <tr>
#       <td id="T_c1eff_row5_col0" class="data row5 col0" >Serenity</td>
#       <td id="T_c1eff_row5_col1" class="data row5 col1" >Science Fiction, Action, Adventure, Thriller</td>
#       <td id="T_c1eff_row5_col2" class="data row5 col2" >3759.000000</td>
#       <td id="T_c1eff_row5_col3" class="data row5 col3" >0.353831</td>
#       <td id="T_c1eff_row5_col4" class="data row5 col4" >0.417646</td>
#     </tr>
#     <tr>
#       <td id="T_c1eff_row6_col0" class="data row6 col0" >Maze Runner: The Death Cure</td>
#       <td id="T_c1eff_row6_col1" class="data row6 col1" >Science Fiction, Action, Adventure, Thriller</td>
#       <td id="T_c1eff_row6_col2" class="data row6 col2" >8208.000000</td>
#       <td id="T_c1eff_row6_col3" class="data row6 col3" >0.339770</td>
#       <td id="T_c1eff_row6_col4" class="data row6 col4" >0.416781</td>
#     </tr>
#     <tr>
#       <td id="T_c1eff_row7_col0" class="data row7 col0" >Star Trek VI: The Undiscovered Country</td>
#       <td id="T_c1eff_row7_col1" class="data row7 col1" >Science Fiction, Action, Adventure, Thriller</td>
#       <td id="T_c1eff_row7_col2" class="data row7 col2" >1367.000000</td>
#       <td id="T_c1eff_row7_col3" class="data row7 col3" >0.365690</td>
#       <td id="T_c1eff_row7_col4" class="data row7 col4" >0.413369</td>
#     </tr>
#     <tr>
#       <td id="T_c1eff_row8_col0" class="data row8 col0" >Kin</td>
#       <td id="T_c1eff_row8_col1" class="data row8 col1" >Science Fiction, Action, Adventure, Thriller</td>
#       <td id="T_c1eff_row8_col2" class="data row8 col2" >869.000000</td>
#       <td id="T_c1eff_row8_col3" class="data row8 col3" >0.362803</td>
#       <td id="T_c1eff_row8_col4" class="data row8 col4" >0.404489</td>
#     </tr>
#     <tr>
#       <td id="T_c1eff_row9_col0" class="data row9 col0" >Firefox</td>
#       <td id="T_c1eff_row9_col1" class="data row9 col1" >Science Fiction, Action, Adventure, Thriller</td>
#       <td id="T_c1eff_row9_col2" class="data row9 col2" >593.000000</td>
#       <td id="T_c1eff_row9_col3" class="data row9 col3" >0.366542</td>
#       <td id="T_c1eff_row9_col4" class="data row9 col4" >0.402249</td>
#     </tr>
#     <tr>
#       <td id="T_c1eff_row10_col0" class="data row10 col0" >Star Trek: Generations</td>
#       <td id="T_c1eff_row10_col1" class="data row10 col1" >Science Fiction, Action, Adventure, Thriller</td>
#       <td id="T_c1eff_row10_col2" class="data row10 col2" >1434.000000</td>
#       <td id="T_c1eff_row10_col3" class="data row10 col3" >0.346444</td>
#       <td id="T_c1eff_row10_col4" class="data row10 col4" >0.397689</td>
#     </tr>
#     <tr>
#       <td id="T_c1eff_row11_col0" class="data row11 col0" >Terminator: Dark Fate</td>
#       <td id="T_c1eff_row11_col1" class="data row11 col1" >Science Fiction, Action, Adventure, Thriller</td>
#       <td id="T_c1eff_row11_col2" class="data row11 col2" >5514.000000</td>
#       <td id="T_c1eff_row11_col3" class="data row11 col3" >0.312327</td>
#       <td id="T_c1eff_row11_col4" class="data row11 col4" >0.387807</td>
#     </tr>
#   </tbody>
# </table>

# %%
results = get_recommendations("dangal", n=12)

if results is not None:
    display(results.style.hide(axis='index'))
# Out:
# ✅ Found matches for: 'Dangal'
# <style type="text/css">
# </style>
# <table id="T_d6eea">
#   <thead>
#     <tr>
#       <th id="T_d6eea_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_d6eea_level0_col1" class="col_heading level0 col1" >genres</th>
#       <th id="T_d6eea_level0_col2" class="col_heading level0 col2" >vote_count</th>
#       <th id="T_d6eea_level0_col3" class="col_heading level0 col3" >similarity</th>
#       <th id="T_d6eea_level0_col4" class="col_heading level0 col4" >hybrid_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d6eea_row0_col0" class="data row0 col0" >Lucky Star</td>
#       <td id="T_d6eea_row0_col1" class="data row0 col1" >Drama, Family, Comedy</td>
#       <td id="T_d6eea_row0_col2" class="data row0 col2" >5.000000</td>
#       <td id="T_d6eea_row0_col3" class="data row0 col3" >0.579087</td>
#       <td id="T_d6eea_row0_col4" class="data row0 col4" >0.517666</td>
#     </tr>
#     <tr>
#       <td id="T_d6eea_row1_col0" class="data row1 col0" >The Longshots</td>
#       <td id="T_d6eea_row1_col1" class="data row1 col1" >Drama, Family, Comedy</td>
#       <td id="T_d6eea_row1_col2" class="data row1 col2" >70.000000</td>
#       <td id="T_d6eea_row1_col3" class="data row1 col3" >0.518033</td>
#       <td id="T_d6eea_row1_col4" class="data row1 col4" >0.500854</td>
#     </tr>
#     <tr>
#       <td id="T_d6eea_row2_col0" class="data row2 col0" >Fahim</td>
#       <td id="T_d6eea_row2_col1" class="data row2 col1" >Drama, Family, Comedy</td>
#       <td id="T_d6eea_row2_col2" class="data row2 col2" >172.000000</td>
#       <td id="T_d6eea_row2_col3" class="data row2 col3" >0.463644</td>
#       <td id="T_d6eea_row2_col4" class="data row2 col4" >0.467269</td>
#     </tr>
#     <tr>
#       <td id="T_d6eea_row3_col0" class="data row3 col0" >Lamer Mother in Law is Friendly to Her Son in Law</td>
#       <td id="T_d6eea_row3_col1" class="data row3 col1" >Drama, Family, Comedy</td>
#       <td id="T_d6eea_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_d6eea_row3_col3" class="data row3 col3" >0.537219</td>
#       <td id="T_d6eea_row3_col4" class="data row3 col4" >0.456636</td>
#     </tr>
#     <tr>
#       <td id="T_d6eea_row4_col0" class="data row4 col0" >Home Sweet Loan</td>
#       <td id="T_d6eea_row4_col1" class="data row4 col1" >Drama, Family, Comedy</td>
#       <td id="T_d6eea_row4_col2" class="data row4 col2" >16.000000</td>
#       <td id="T_d6eea_row4_col3" class="data row4 col3" >0.478839</td>
#       <td id="T_d6eea_row4_col4" class="data row4 col4" >0.447242</td>
#     </tr>
#     <tr>
#       <td id="T_d6eea_row5_col0" class="data row5 col0" >Shakuntala Devi</td>
#       <td id="T_d6eea_row5_col1" class="data row5 col1" >Drama, Family, Comedy</td>
#       <td id="T_d6eea_row5_col2" class="data row5 col2" >35.000000</td>
#       <td id="T_d6eea_row5_col3" class="data row5 col3" >0.462288</td>
#       <td id="T_d6eea_row5_col4" class="data row5 col4" >0.443827</td>
#     </tr>
#     <tr>
#       <td id="T_d6eea_row6_col0" class="data row6 col0" >The Better Half</td>
#       <td id="T_d6eea_row6_col1" class="data row6 col1" >Drama, Family, Comedy</td>
#       <td id="T_d6eea_row6_col2" class="data row6 col2" >4.000000</td>
#       <td id="T_d6eea_row6_col3" class="data row6 col3" >0.477446</td>
#       <td id="T_d6eea_row6_col4" class="data row6 col4" >0.428682</td>
#     </tr>
#     <tr>
#       <td id="T_d6eea_row7_col0" class="data row7 col0" >Skippy</td>
#       <td id="T_d6eea_row7_col1" class="data row7 col1" >Drama, Family, Comedy</td>
#       <td id="T_d6eea_row7_col2" class="data row7 col2" >23.000000</td>
#       <td id="T_d6eea_row7_col3" class="data row7 col3" >0.436175</td>
#       <td id="T_d6eea_row7_col4" class="data row7 col4" >0.415875</td>
#     </tr>
#     <tr>
#       <td id="T_d6eea_row8_col0" class="data row8 col0" >Sweet Agony 2</td>
#       <td id="T_d6eea_row8_col1" class="data row8 col1" >Drama, Family, Comedy</td>
#       <td id="T_d6eea_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_d6eea_row8_col3" class="data row8 col3" >0.484607</td>
#       <td id="T_d6eea_row8_col4" class="data row8 col4" >0.411916</td>
#     </tr>
#     <tr>
#       <td id="T_d6eea_row9_col0" class="data row9 col0" >Khali Purse of Billionaires</td>
#       <td id="T_d6eea_row9_col1" class="data row9 col1" >Drama, Family, Comedy</td>
#       <td id="T_d6eea_row9_col2" class="data row9 col2" >3.000000</td>
#       <td id="T_d6eea_row9_col3" class="data row9 col3" >0.457904</td>
#       <td id="T_d6eea_row9_col4" class="data row9 col4" >0.408903</td>
#     </tr>
#     <tr>
#       <td id="T_d6eea_row10_col0" class="data row10 col0" >A Grandson from America</td>
#       <td id="T_d6eea_row10_col1" class="data row10 col1" >Drama, Family, Comedy</td>
#       <td id="T_d6eea_row10_col2" class="data row10 col2" >8.000000</td>
#       <td id="T_d6eea_row10_col3" class="data row10 col3" >0.441979</td>
#       <td id="T_d6eea_row10_col4" class="data row10 col4" >0.406880</td>
#     </tr>
#     <tr>
#       <td id="T_d6eea_row11_col0" class="data row11 col0" >Apne Paraye</td>
#       <td id="T_d6eea_row11_col1" class="data row11 col1" >Drama, Family, Comedy</td>
#       <td id="T_d6eea_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_d6eea_row11_col3" class="data row11 col3" >0.473341</td>
#       <td id="T_d6eea_row11_col4" class="data row11 col4" >0.402339</td>
#     </tr>
#   </tbody>
# </table>

# %%
results = get_recommendations("sholay", n=12)

if results is not None:
    display(results.style.hide(axis='index'))
# Out:
# ✅ Found matches for: 'Sholay'
# <style type="text/css">
# </style>
# <table id="T_76084">
#   <thead>
#     <tr>
#       <th id="T_76084_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_76084_level0_col1" class="col_heading level0 col1" >genres</th>
#       <th id="T_76084_level0_col2" class="col_heading level0 col2" >vote_count</th>
#       <th id="T_76084_level0_col3" class="col_heading level0 col3" >similarity</th>
#       <th id="T_76084_level0_col4" class="col_heading level0 col4" >hybrid_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_76084_row0_col0" class="data row0 col0" >Sholay: The Final Cut</td>
#       <td id="T_76084_row0_col1" class="data row0 col1" >Action, Adventure, Crime, Comedy, Thriller</td>
#       <td id="T_76084_row0_col2" class="data row0 col2" >2.000000</td>
#       <td id="T_76084_row0_col3" class="data row0 col3" >0.594830</td>
#       <td id="T_76084_row0_col4" class="data row0 col4" >0.521205</td>
#     </tr>
#     <tr>
#       <td id="T_76084_row1_col0" class="data row1 col0" >Maa Kasam</td>
#       <td id="T_76084_row1_col1" class="data row1 col1" >Action</td>
#       <td id="T_76084_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_76084_row1_col3" class="data row1 col3" >0.317077</td>
#       <td id="T_76084_row1_col4" class="data row1 col4" >0.279358</td>
#     </tr>
#     <tr>
#       <td id="T_76084_row2_col0" class="data row2 col0" >Munnibai</td>
#       <td id="T_76084_row2_col1" class="data row2 col1" >Action</td>
#       <td id="T_76084_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_76084_row2_col3" class="data row2 col3" >0.312692</td>
#       <td id="T_76084_row2_col4" class="data row2 col4" >0.275630</td>
#     </tr>
#     <tr>
#       <td id="T_76084_row3_col0" class="data row3 col0" >Desh Premee</td>
#       <td id="T_76084_row3_col1" class="data row3 col1" >Action, Drama</td>
#       <td id="T_76084_row3_col2" class="data row3 col2" >6.000000</td>
#       <td id="T_76084_row3_col3" class="data row3 col3" >0.290772</td>
#       <td id="T_76084_row3_col4" class="data row3 col4" >0.274786</td>
#     </tr>
#     <tr>
#       <td id="T_76084_row4_col0" class="data row4 col0" >Garota da Moto</td>
#       <td id="T_76084_row4_col1" class="data row4 col1" >Action</td>
#       <td id="T_76084_row4_col2" class="data row4 col2" >12.000000</td>
#       <td id="T_76084_row4_col3" class="data row4 col3" >0.277728</td>
#       <td id="T_76084_row4_col4" class="data row4 col4" >0.272489</td>
#     </tr>
#     <tr>
#       <td id="T_76084_row5_col0" class="data row5 col0" >A Gamer's Day</td>
#       <td id="T_76084_row5_col1" class="data row5 col1" >Action</td>
#       <td id="T_76084_row5_col2" class="data row5 col2" >5.000000</td>
#       <td id="T_76084_row5_col3" class="data row5 col3" >0.277728</td>
#       <td id="T_76084_row5_col4" class="data row5 col4" >0.261510</td>
#     </tr>
#     <tr>
#       <td id="T_76084_row6_col0" class="data row6 col0" >Ganga Ki Saugand</td>
#       <td id="T_76084_row6_col1" class="data row6 col1" >Action, Romance</td>
#       <td id="T_76084_row6_col2" class="data row6 col2" >3.000000</td>
#       <td id="T_76084_row6_col3" class="data row6 col3" >0.283400</td>
#       <td id="T_76084_row6_col4" class="data row6 col4" >0.260574</td>
#     </tr>
#     <tr>
#       <td id="T_76084_row7_col0" class="data row7 col0" >El Diamante de Caro Quintero</td>
#       <td id="T_76084_row7_col1" class="data row7 col1" >Action</td>
#       <td id="T_76084_row7_col2" class="data row7 col2" >4.000000</td>
#       <td id="T_76084_row7_col3" class="data row7 col3" >0.277728</td>
#       <td id="T_76084_row7_col4" class="data row7 col4" >0.258922</td>
#     </tr>
#     <tr>
#       <td id="T_76084_row8_col0" class="data row8 col0" >With the Devil in the Blood</td>
#       <td id="T_76084_row8_col1" class="data row8 col1" >Action</td>
#       <td id="T_76084_row8_col2" class="data row8 col2" >4.000000</td>
#       <td id="T_76084_row8_col3" class="data row8 col3" >0.277728</td>
#       <td id="T_76084_row8_col4" class="data row8 col4" >0.258922</td>
#     </tr>
#     <tr>
#       <td id="T_76084_row9_col0" class="data row9 col0" >Sentencia de narcoticos</td>
#       <td id="T_76084_row9_col1" class="data row9 col1" >Action</td>
#       <td id="T_76084_row9_col2" class="data row9 col2" >4.000000</td>
#       <td id="T_76084_row9_col3" class="data row9 col3" >0.277728</td>
#       <td id="T_76084_row9_col4" class="data row9 col4" >0.258922</td>
#     </tr>
#     <tr>
#       <td id="T_76084_row10_col0" class="data row10 col0" >500 Balazos 2 (El principio)</td>
#       <td id="T_76084_row10_col1" class="data row10 col1" >Action</td>
#       <td id="T_76084_row10_col2" class="data row10 col2" >4.000000</td>
#       <td id="T_76084_row10_col3" class="data row10 col3" >0.277728</td>
#       <td id="T_76084_row10_col4" class="data row10 col4" >0.258922</td>
#     </tr>
#     <tr>
#       <td id="T_76084_row11_col0" class="data row11 col0" >Comando judicial</td>
#       <td id="T_76084_row11_col1" class="data row11 col1" >Action</td>
#       <td id="T_76084_row11_col2" class="data row11 col2" >3.000000</td>
#       <td id="T_76084_row11_col3" class="data row11 col3" >0.277728</td>
#       <td id="T_76084_row11_col4" class="data row11 col4" >0.255753</td>
#     </tr>
#   </tbody>
# </table>

# %%
results = get_recommendations("pK", n=12)

if results is not None:
    display(results.style.hide(axis='index'))
# Out:
# ⚠️ Search term 'pK' is too vague.

# %%
# Check if popular movies exist
test_titles = [
    "Dune: Part Two",
    "Mad Max: Fury Road", 
    "Mission: Impossible - Fallout",
    "Blade Runner 2049"
]

for title in test_titles:
    if title in df['title'].values:
        print(f"✓ {title} exists")
    else:
        print(f"✗ {title} MISSING")
# Out:
# ✓ Dune: Part Two exists
# ✓ Mad Max: Fury Road exists
# ✓ Mission: Impossible - Fallout exists
# ✓ Blade Runner 2049 exists

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 # Check Bollywood representation
# ----> 2 print(f"Total Bollywood movies: {len(bollywood_movies)}")
#       3 print(f"Average votes: {bollywood_movies['vote_count'].mean()}")
#       4 print(f"Movies with >1000 votes: {(bollywood_movies['vote_count'] > 1000).sum()}")
#
# NameError: name 'bollywood_movies' is not defined
